# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime

# Import API key
from api_keys import sport_key

# %%
data_year = '2018'
standings_url = f"http://api.sportradar.us/nfl/official/trial/v5/en/seasons/{data_year}/standings.json?"

standings_query_url = f"{standings_url}api_key={sport_key}"

standings_response = requests.get(standings_query_url)
standings_json = standings_response.json()

# %%
teams = []
team_data = []

for conference in range(len(standings_json['conferences'])):

    for division in range(len(standings_json['conferences'][conference])):
        
        for team in range(len(standings_json['conferences'][conference]['divisions'][division])):
            
            teams.append({
            'Season_Year'   : standings_json['season']['year'],
            'Season_Type'   : standings_json['season']['type'],
            'Conference'    : standings_json['conferences'][conference]['name'],
            'Division'      : standings_json['conferences'][conference]['divisions'][division]['name'],
            'Team_Name'     : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['name'],
            'Team_ID'       : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['id'],
            'Wins'          : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['wins'],
            'Losses'        : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['losses'],         
            'Ties'          : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['ties'],
            'Win_pct'       : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['win_pct'],
            'Points_for'    : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_for'],
            'Points_against': standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_against'],
            'Points_rank'   : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_rank'],
            'Touchdown_diff': standings_json['conferences'][conference]['divisions'][division]['teams'][team]['touchdown_diff'],
        })
            
teams_df = pd.DataFrame(teams)
teams_df.to_csv(f"Resources/standings_{data_year}.csv", index=False)
teams_df.groupby(['Conference','Division', 'Team_Name']).mean()
# Out:
#                                  Losses  Points_against  Points_for  \
# Conference Division  Team_Name
# AFC        AFC East  Bills            7             289         343
#                      Dolphins         8             373         388
#                      Jets            12             401         283
#                      Patriots         4             313         468
#            AFC North Bengals          5             344         365
#                      Browns           9             337         299
#                      Ravens           6             302         409
#                      Steelers         5             368         436
#            AFC South Colts            5             369         458
#                      Jaguars         13             412         249
#                      Texans           7             307         372
#                      Titans          14             438         254
#            AFC West  Broncos          4             354         482
#                      Chargers         7             348         348
#                      Chiefs           7             281         353
#                      Raiders         13             452         253
# NFC        NFC East  Cowboys          4             352         467
#                      Eagles           6             400         474
#                      Giants          10             400         380
#                      Redskins        12             438         301
#            NFC North Bears           11             442         319
#                      Lions            5             282         321
#                      Packers          4             348         486
#                      Vikings          9             343         325
#            NFC South Buccaneers      14             410         277
#                      Falcons         10             417         381
#                      Panthers         8             374         339
#                      Saints           9             424         401
#            NFC West  49ers            8             340         306
#                      Cardinals        5             299         310
#                      Rams            10             354         324
#                      Seahawks         4             254         394
#
#                                  Points_rank  Season_Year  Ties  \
# Conference Division  Team_Name
# AFC        AFC East  Bills                22         2014     0
#                      Dolphins             31         2014     0
#                      Jets                 52         2014     0
#                      Patriots             12         2014     0
#            AFC North Bengals              27         2014     1
#                      Browns               36         2014     0
#                      Ravens               14         2014     0
#                      Steelers             25         2014     0
#            AFC South Colts                25         2014     0
#                      Jaguars              58         2014     0
#                      Texans               21         2014     0
#                      Titans               59         2014     0
#            AFC West  Broncos              18         2014     0
#                      Chargers             30         2014     0
#                      Chiefs               18         2014     0
#                      Raiders              63         2014     0
# NFC        NFC East  Cowboys              20         2014     0
#                      Eagles               25         2014     0
#                      Giants               35         2014     0
#                      Redskins             55         2014     0
#            NFC North Bears                54         2014     0
#                      Lions                25         2014     0
#                      Packers              14         2014     0
#                      Vikings              31         2014     0
#            NFC South Buccaneers           54         2014     0
#                      Falcons              39         2014     0
#                      Panthers             40         2014     1
#                      Saints               37         2014     0
#            NFC West  49ers                35         2014     0
#                      Cardinals            29         2014     0
#                      Rams                 37         2014     0
#                      Seahawks             11         2014     0
#
#                                  Touchdown_diff  Win_pct  Wins
# Conference Division  Team_Name
# AFC        AFC East  Bills                    6    0.563     9
#                      Dolphins                 0    0.500     8
#                      Jets                   -19    0.250     4
#                      Patriots                20    0.750    12
#            AFC North Bengals                  2    0.656    10
#                      Browns                  -4    0.438     7
#                      Ravens                  16    0.625    10
#                      Steelers                 9    0.688    11
#            AFC South Colts                    7    0.688    11
#                      Jaguars                -18    0.188     3
#                      Texans                   4    0.563     9
#                      Titans                 -20    0.125     2
#            AFC West  Broncos                 17    0.750    12
#                      Chargers                 2    0.563     9
#                      Chiefs                  14    0.563     9
#                      Raiders                -23    0.188     3
# NFC        NFC East  Cowboys                 13    0.750    12
#                      Eagles                   6    0.625    10
#                      Giants                  -1    0.375     6
#                      Redskins               -20    0.250     4
#            NFC North Bears                   -9    0.313     5
#                      Lions                    3    0.688    11
#                      Packers                 18    0.750    12
#                      Vikings                 -3    0.438     7
#            NFC South Buccaneers             -15    0.125     2
#                      Falcons                 -4    0.375     6
#                      Panthers                -8    0.469     7
#                      Saints                   2    0.438     7
#            NFC West  49ers                   -7    0.500     8
#                      Cardinals                0    0.688    11
#                      Rams                    -4    0.375     6
#                      Seahawks                16    0.750    12

# %%
all_teams_season = []

for team in range(len(teams_df)):
    print(f"Loop #{team} Collecting data for {teams_df.Team_Name[team]} team")
     
    season_url = f"http://api.sportradar.us/nfl/official/trial/v5/en/seasons/{data_year}/REG/teams/{teams_df.Team_ID[team]}/statistics.json?"
    season_query_url = f"{season_url}api_key={sport_key}"
    season_response = requests.get(season_query_url)
    all_teams_season.append(season_response.json())
    
    time.sleep(1)
            
print("------------------")
print("Process Completed")

all_teams_season_df = pd.DataFrame(all_teams_season)
all_teams_season_df.to_csv(f"Resources/all_teams_season_{data_year}.csv", index=False)
# Out:
# Loop #0 Collecting data for Patriots team
# Loop #1 Collecting data for Bills team
# Loop #2 Collecting data for Dolphins team
# Loop #3 Collecting data for Jets team
# Loop #4 Collecting data for Steelers team
# Loop #5 Collecting data for Bengals team
# Loop #6 Collecting data for Ravens team
# Loop #7 Collecting data for Browns team
# Loop #8 Collecting data for Colts team
# Loop #9 Collecting data for Texans team
# Loop #10 Collecting data for Jaguars team
# Loop #11 Collecting data for Titans team
# Loop #12 Collecting data for Broncos team
# Loop #13 Collecting data for Chiefs team
# Loop #14 Collecting data for Chargers team
# Loop #15 Collecting data for Raiders team
# Loop #16 Collecting data for Cowboys team
# Loop #17 Collecting data for Eagles team
# Loop #18 Collecting data for Giants team
# Loop #19 Collecting data for Redskins team
# Loop #20 Collecting data for Packers team
# Loop #21 Collecting data for Lions team
# Loop #22 Collecting data for Vikings team
# Loop #23 Collecting data for Bears team
# Loop #24 Collecting data for Panthers team
# Loop #25 Collecting data for Saints team
# Loop #26 Collecting data for Falcons team
# Loop #27 Collecting data for Buccaneers team
# Loop #28 Collecting data for Seahawks team
# Loop #29 Collecting data for Cardinals team
# Loop #30 Collecting data for 49ers team
# Loop #31 Collecting data for Rams team
# ------------------
# Process Completed

# %%
all_teams_season_df['players'][0][0].keys()
# Out:
# dict_keys(['id', 'name', 'jersey', 'reference', 'position', 'games_played', 'games_started', 'receiving'])

# %%
#all_teams_season_df['players'][30][0].keys()

players = []

for team in range(len(all_teams_season_df['name'])):
    for player in range(len(all_teams_season_df['players'][team])):
            if 'position' in all_teams_season_df['players'][team][player].keys():
                  players.append({
                    'Team_name'  : all_teams_season_df['name'][team],
                    'Season_Year': all_teams_season_df['season'][0]['year'],
                    'Player_Name': all_teams_season_df['players'][team][player]['name'],
                    'Player_ID'  : all_teams_season_df['players'][team][player]['id'],
                    'Position'   : all_teams_season_df['players'][team][player]['position'],
                    })

all_players_df = pd.DataFrame(players)
all_players_df.to_csv(f"Resources/all_players_{data_year}.csv", index=False)
all_players_df
# Out:
#                                  Player_ID         Player_Name Position  \
# 0     0268a19e-6227-4fba-83fd-6aa52176dc3a        Steve Maneri       TE
# 1     05526dc5-8397-4741-81bb-46ef2aba446e        Bruce Gaston       DT
# 2     0ad26168-7f0e-4eb9-8776-7166b5ebab16     Brandon Browner       CB
# 3     10616740-2c72-4207-b8ed-9da09ecba854        Ryan Wendell        G
# 4     170b4c5f-a345-4899-8d81-e8982b0f3d65       Stevan Ridley       RB
# 5     191d31c5-46ff-4e35-ab6e-fc77e1fad7cf      Darius Fleming      OLB
# 6     1dae3683-fa88-45af-bb18-34dcc09210c7       Vince Wilfork       NT
# 7     2142a164-48ad-47d6-bb27-0bc58c6b2e62      Rob Gronkowski       TE
# 8     248b6e0b-bb1b-4dd7-8eb2-b5f7e98c77b1     Cameron Fleming        T
# 9     28a2a255-9227-4a5f-a4ec-0ee4b2bf629b          Jerod Mayo      MLB
# 10    2979c3a5-0e4e-489e-82d7-d208e48b828b      Darrelle Revis       CB
# 11    2b4e17f2-27b8-4c98-9b27-1d4c0d7949de  Kenbrell Thompkins       WR
# 12    2bb70d56-a79a-4fa1-ae37-99858a3ffd55      Julian Edelman       WR
# 2134  d228c128-0237-40d0-8f8e-d82fbb852bf5        Matt Conrath       DE
# 2135  d53cd589-73d6-4aad-ae69-e979670a0d14      Rodger Saffold        T
# 2136  d954bad7-541b-43d5-9918-ef1cead10b13       Joe Barksdale        T
# 2137  dcb2f697-f9f6-4ffa-a417-3f2ec2229a5a        Will Herring       LB
# 2138  de9e506f-e683-4d15-9d91-ef9625fa74f3  Brandon Washington        G
# 2139  e0e55096-4f50-42e3-897c-663017220b56           Jake Long        T
# 2140  e0f05175-f652-4f5e-9931-068a712291e6       T.J. McDonald       SS
# 2141  e4538897-a749-41a8-8220-332e8229ac41    Trumaine Johnson       CB
# 2142  e7932199-4d0f-4a94-9f96-dd752d594d56          Trey Watts       RB
# 2143  eb881031-ffac-4e6e-80c3-fdfbc6272642       Barrett Jones        C
# 2144  f2619e8d-82a1-4042-831b-a7035dfa71fb   Marshall McFadden       LB
# 2145  f34a5499-7aed-47e9-bcde-793f008ed0d4     Alex Carrington       DE
# 2146  f8ca735c-2779-4d0c-914e-e58e11c2356d         Brian Quick       WR
# 2147  f963be41-d1a9-4410-8e8d-c21dcbaae24b      Chase Reynolds       RB
# 2148  fa8cfe11-018a-4d4c-9588-c86cab0415c0        Austin Davis       QB
#
#       Season_Year Team_name
# 0            2014  Patriots
# 1            2014  Patriots
# 2            2014  Patriots
# 3            2014  Patriots
# 4            2014  Patriots
# 5            2014  Patriots
# 6            2014  Patriots
# 7            2014  Patriots
# 8            2014  Patriots
# 9            2014  Patriots
# 10           2014  Patriots
# 11           2014  Patriots
# 12           2014  Patriots
# 13           2014  Patriots
# 14           2014  Patriots
# 15           2014  Patriots
# 16           2014  Patriots
# 17           2014  Patriots
# 18           2014  Patriots
# 19           2014  Patriots
# 20           2014  Patriots
# 21           2014  Patriots
# 22           2014  Patriots
# 23           2014  Patriots
# 24           2014  Patriots
# 25           2014  Patriots
# 26           2014  Patriots
# 27           2014  Patriots
# 28           2014  Patriots
# 29           2014  Patriots
# ...           ...       ...
# 2119         2014      Rams
# 2120         2014      Rams
# 2121         2014      Rams
# 2122         2014      Rams
# 2123         2014      Rams
# 2124         2014      Rams
# 2125         2014      Rams
# 2126         2014      Rams
# 2127         2014      Rams
# 2128         2014      Rams
# 2129         2014      Rams
# 2130         2014      Rams
# 2131         2014      Rams
# 2132         2014      Rams
# 2133         2014      Rams
# 2134         2014      Rams
# 2135         2014      Rams
# 2136         2014      Rams
# 2137         2014      Rams
# 2138         2014      Rams
# 2139         2014      Rams
# 2140         2014      Rams
# 2141         2014      Rams
# 2142         2014      Rams
# 2143         2014      Rams
# 2144         2014      Rams
# 2145         2014      Rams
# 2146         2014      Rams
# 2147         2014      Rams
# 2148         2014      Rams
#
# [2149 rows x 5 columns]
