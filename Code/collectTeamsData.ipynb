# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import datetime

# Import API key
from api_keys import sport_key

# %%
data_year = '2014'
standings_url = f"http://api.sportradar.us/nfl/official/trial/v5/en/seasons/{data_year}/standings.json?"

standings_query_url = f"{standings_url}api_key={sport_key}"

standings_response = requests.get(standings_query_url)
standings_json = standings_response.json()

# %%
teams = []
team_data = []

for conference in range(len(standings_json['conferences'])):

    for division in range(len(standings_json['conferences'][conference])):
        
        for team in range(len(standings_json['conferences'][conference]['divisions'][division])):
            
            teams.append({
            'Season_Year'   : standings_json['season']['year'],
            'Season_Type'   : standings_json['season']['type'],
            'Conference'    : standings_json['conferences'][conference]['name'],
            'Division'      : standings_json['conferences'][conference]['divisions'][division]['name'],
            'Team_Name'     : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['name'],
            'Team_ID'       : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['id'],
            'Wins'          : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['wins'],
            'Losses'        : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['losses'],         
            'Ties'          : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['ties'],
            'Win_pct'       : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['win_pct'],
            'Points_for'    : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_for'],
            'Points_against': standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_against'],
            'Points_rank'   : standings_json['conferences'][conference]['divisions'][division]['teams'][team]['points_rank'],
            'Touchdown_diff': standings_json['conferences'][conference]['divisions'][division]['teams'][team]['touchdown_diff'],
        })
            
teams_df = pd.DataFrame(teams)
teams_df.to_csv(f"Resources/standings_{data_year}.csv", index=False)
teams_df.groupby(['Conference','Division', 'Team_Name']).mean()
# Out:
#                                  Losses  Points_against  Points_for  \
# Conference Division  Team_Name
# AFC        AFC East  Bills            7             289         343
#                      Dolphins         8             373         388
#                      Jets            12             401         283
#                      Patriots         4             313         468
#            AFC North Bengals          5             344         365
#                      Browns           9             337         299
#                      Ravens           6             302         409
#                      Steelers         5             368         436
#            AFC South Colts            5             369         458
#                      Jaguars         13             412         249
#                      Texans           7             307         372
#                      Titans          14             438         254
#            AFC West  Broncos          4             354         482
#                      Chargers         7             348         348
#                      Chiefs           7             281         353
#                      Raiders         13             452         253
# NFC        NFC East  Cowboys          4             352         467
#                      Eagles           6             400         474
#                      Giants          10             400         380
#                      Redskins        12             438         301
#            NFC North Bears           11             442         319
#                      Lions            5             282         321
#                      Packers          4             348         486
#                      Vikings          9             343         325
#            NFC South Buccaneers      14             410         277
#                      Falcons         10             417         381
#                      Panthers         8             374         339
#                      Saints           9             424         401
#            NFC West  49ers            8             340         306
#                      Cardinals        5             299         310
#                      Rams            10             354         324
#                      Seahawks         4             254         394
#
#                                  Points_rank  Season_Year  Ties  \
# Conference Division  Team_Name
# AFC        AFC East  Bills                22         2014     0
#                      Dolphins             31         2014     0
#                      Jets                 52         2014     0
#                      Patriots             12         2014     0
#            AFC North Bengals              27         2014     1
#                      Browns               36         2014     0
#                      Ravens               14         2014     0
#                      Steelers             25         2014     0
#            AFC South Colts                25         2014     0
#                      Jaguars              58         2014     0
#                      Texans               21         2014     0
#                      Titans               59         2014     0
#            AFC West  Broncos              18         2014     0
#                      Chargers             30         2014     0
#                      Chiefs               18         2014     0
#                      Raiders              63         2014     0
# NFC        NFC East  Cowboys              20         2014     0
#                      Eagles               25         2014     0
#                      Giants               35         2014     0
#                      Redskins             55         2014     0
#            NFC North Bears                54         2014     0
#                      Lions                25         2014     0
#                      Packers              14         2014     0
#                      Vikings              31         2014     0
#            NFC South Buccaneers           54         2014     0
#                      Falcons              39         2014     0
#                      Panthers             40         2014     1
#                      Saints               37         2014     0
#            NFC West  49ers                35         2014     0
#                      Cardinals            29         2014     0
#                      Rams                 37         2014     0
#                      Seahawks             11         2014     0
#
#                                  Touchdown_diff  Win_pct  Wins
# Conference Division  Team_Name
# AFC        AFC East  Bills                    6    0.563     9
#                      Dolphins                 0    0.500     8
#                      Jets                   -19    0.250     4
#                      Patriots                20    0.750    12
#            AFC North Bengals                  2    0.656    10
#                      Browns                  -4    0.438     7
#                      Ravens                  16    0.625    10
#                      Steelers                 9    0.688    11
#            AFC South Colts                    7    0.688    11
#                      Jaguars                -18    0.188     3
#                      Texans                   4    0.563     9
#                      Titans                 -20    0.125     2
#            AFC West  Broncos                 17    0.750    12
#                      Chargers                 2    0.563     9
#                      Chiefs                  14    0.563     9
#                      Raiders                -23    0.188     3
# NFC        NFC East  Cowboys                 13    0.750    12
#                      Eagles                   6    0.625    10
#                      Giants                  -1    0.375     6
#                      Redskins               -20    0.250     4
#            NFC North Bears                   -9    0.313     5
#                      Lions                    3    0.688    11
#                      Packers                 18    0.750    12
#                      Vikings                 -3    0.438     7
#            NFC South Buccaneers             -15    0.125     2
#                      Falcons                 -4    0.375     6
#                      Panthers                -8    0.469     7
#                      Saints                   2    0.438     7
#            NFC West  49ers                   -7    0.500     8
#                      Cardinals                0    0.688    11
#                      Rams                    -4    0.375     6
#                      Seahawks                16    0.750    12

# %%
all_teams_season = []

for team in range(len(teams_df)):
    print(f"Loop #{team} Collecting data for {teams_df.Team_Name[team]} team")
     
    season_url = f"http://api.sportradar.us/nfl/official/trial/v5/en/seasons/{data_year}/REG/teams/{teams_df.Team_ID[team]}/statistics.json?"
    season_query_url = f"{season_url}api_key={sport_key}"
    season_response = requests.get(season_query_url)
    all_teams_season.append(season_response.json())
    
    for x in range(10000005):
          y = x
            
print("------------------")
print("Process Completed")

all_teams_season_df = pd.DataFrame(all_teams_season)
all_teams_season_df.to_csv(f"Resources/all_teams_season_{data_year}.csv", index=False)
# Out:
# Loop #0 Collecting data for Patriots team
# Loop #1 Collecting data for Bills team
# Loop #2 Collecting data for Dolphins team
# Loop #3 Collecting data for Jets team
# Loop #4 Collecting data for Steelers team
# Loop #5 Collecting data for Bengals team
# Loop #6 Collecting data for Ravens team
# Loop #7 Collecting data for Browns team
# Loop #8 Collecting data for Colts team
# Loop #9 Collecting data for Texans team
# Loop #10 Collecting data for Jaguars team
# Loop #11 Collecting data for Titans team
# Loop #12 Collecting data for Broncos team
# Loop #13 Collecting data for Chiefs team
# Loop #14 Collecting data for Chargers team
# Loop #15 Collecting data for Raiders team
# Loop #16 Collecting data for Cowboys team
# Loop #17 Collecting data for Eagles team
# Loop #18 Collecting data for Giants team
# Loop #19 Collecting data for Redskins team
# Loop #20 Collecting data for Packers team
# Loop #21 Collecting data for Lions team
# Loop #22 Collecting data for Vikings team
# Loop #23 Collecting data for Bears team
# Loop #24 Collecting data for Panthers team
# Loop #25 Collecting data for Saints team
# Loop #26 Collecting data for Falcons team
# Loop #27 Collecting data for Buccaneers team
# Loop #28 Collecting data for Seahawks team
# Loop #29 Collecting data for Cardinals team
# Loop #30 Collecting data for 49ers team
# Loop #31 Collecting data for Rams team
# ------------------
# Process Completed

# %%
all_teams_season_df['players'][0][0]['position']
# Out:
# 'TE'
